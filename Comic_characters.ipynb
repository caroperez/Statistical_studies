# %% [markdown]
# # Comics

# %% [markdown]
# We have 8 different datasets on comic book characters. We are going to make a small exploration of the data to see what kind of analysis we can make that is interesting.

# %%
# package required
import pandas as pd

# load de file of dataset
chart = pd.read_csv("datasets/heroes_characters.csv") # number of ID characters
chart_stats = pd.read_csv("datasets/heroes_charcters_stats.csv") # statistics of characters
chart_to_comics = pd.read_csv("datasets/heroes_charactersToComics.csv") # numbers characters ID and comic ID where appears
chart_comics = pd.read_csv("datasets/heroes_comics.csv") # number ID comic, name, issuenumber and description
chart_info = pd.read_csv("datasets/heroes_marvel_characters_info.csv") # number ID characters and info about (include publisher)
marvel_dc_chart = pd.read_excel("datasets/heroes_marvel_dc_characters.xlsx") # ID number and description characters with appears date
power_matrix = pd.read_csv("datasets/heroes_superheroes_power_matrix.csv") # ID characters and powers

# %%
# Out:
#           Name  Agility  Accelerated Healing  Lantern Power Ring  \
# 0      3-D Man     True                False               False
# 1       A-Bomb    False                 True               False
# 2   Abe Sapien     True                 True               False
# 3     Abin Sur    False                False                True
# 4  Abomination    False                 True               False
#
#    Dimensional Awareness  Cold Resistance  Durability  Stealth  \
# 0                  False            False       False    False
# 1                  False            False        True    False
# 2                  False             True        True    False
# 3                  False            False       False    False
# 4                  False            False       False    False
#
#    Energy Absorption  Flight  ...  Web Creation  Reality Warping  Odin Force  \
# 0              False   False  ...         False            False       False
# ...
