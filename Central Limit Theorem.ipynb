# %% [markdown]
# # Central Limit Theorem

# %% [markdown]
# The central limit theorem is a mathematical theory that explains that before a sufficiently large and random sample, it is observed that the distribution of its mean and variances follow a Gaussian or normal distribution.

# %%
# packages needed
import numpy as np
import matplotlib.pyplot as plt

# seed for replications
np.random.seed(13579)

# %%
# number of samples
sm = [1, 10, 100, 1000, 10000, 1000000]

# list for save means
means = []

# generate randoms numbers
for i in sm:
    data = [np.mean(np.random.randint(-40, 40, i)) for j in range(1000)]
    means.append(data)

# %%
# %matplotlib inline

## define object for position data to plot
k = 0

# plotting all the means in one figure 
fig, ax = plt.subplots(2, 3, figsize =(8, 8)) 

for i in range(0, 2): 
    for j in range(0, 3): 
        # Histogram for each x stored in means 
        ax[i, j].hist(means[k], 40, density = True) 
        ax[i, j].set_title(label = sm[k]) 
        k = k + 1

plt.show()
